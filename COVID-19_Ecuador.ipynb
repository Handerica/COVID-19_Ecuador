# %% [markdown]
# # Choropleth map with markers of the COVID-19 in Ecuador

# %% [markdown]
# This Notebook will be a guide on how to create a choropleth map of Ecuador based in the data given by the public health authorities from Ecuador (Ministerio de salud Publica, MSP).
# <br>
# __Note:__ To fully understand this notebook it is needed basic knowledge of pandas dataframes and folium python library.

# %% [markdown]
# ## Installation of the libraries that are going to be used

# %%
# !pip install folium
# !pip install pandas
# Out:
# Requirement already satisfied: folium in c:\users\hugoa\anaconda3\lib\site-packages (0.10.1)
# Requirement already satisfied: jinja2>=2.9 in c:\users\hugoa\anaconda3\lib\site-packages (from folium) (2.10)
# Requirement already satisfied: numpy in c:\users\hugoa\anaconda3\lib\site-packages (from folium) (1.15.4)
# Requirement already satisfied: requests in c:\users\hugoa\anaconda3\lib\site-packages (from folium) (2.21.0)
# Requirement already satisfied: branca>=0.3.0 in c:\users\hugoa\anaconda3\lib\site-packages (from folium) (0.4.0)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\hugoa\anaconda3\lib\site-packages (from jinja2>=2.9->folium) (1.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\hugoa\anaconda3\lib\site-packages (from requests->folium) (2018.11.29)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\users\hugoa\anaconda3\lib\site-packages (from requests->folium) (3.0.4)
# Requirement already satisfied: idna<2.9,>=2.5 in c:\users\hugoa\anaconda3\lib\site-packages (from requests->folium) (2.8)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in c:\users\hugoa\anaconda3\lib\site-packages (from requests->folium) (1.24.1)
# Requirement already satisfied: six in c:\users\hugoa\anaconda3\lib\site-packages (from branca>=0.3.0->folium) (1.12.0)
# Requirement already satisfied: pandas in c:\users\hugoa\anaconda3\lib\site-packages (0.23.4)
# Requirement already satisfied: python-dateutil>=2.5.0 in c:\users\hugoa\anaconda3\lib\site-packages (from pandas) (2.7.5)
# Requirement already satisfied: pytz>=2011k in c:\users\hugoa\anaconda3\lib\site-packages (from pandas) (2018.7)
# Requirement already satisfied: numpy>=1.9.0 in c:\users\hugoa\anaconda3\lib\site-packages (from pandas) (1.15.4)
# Requirement already satisfied: six>=1.5 in c:\users\hugoa\anaconda3\lib\site-packages (from python-dateutil>=2.5.0->pandas) (1.12.0)

# %% [markdown]
# ## Import libraries

# %% [markdown]
# __Note:__ os and webbrowser libraries are default libraries, so there is no need to install them.

# %%
import pandas as pd
import folium
import os 
import webbrowser

# %% [markdown]
# ## Reading Base_covid19_msp_23abr2020.csv file using pandas

# %% [markdown]
# This file contains a list of all the COVID-19 tests realized in Ecuador until April 23th, 2020.
# <br>
# __sep=';'__ defines that the separation character will be ";" and not "," which is set by default.
# <br>
# __header='infer'__ defines that the headers will be the same names shown in the first row of the .csv file.
# <br>
# __encoding='ISO-8859-1'__ is a very common encoding used to read .csv files.

# %%
df_COVID_EC = pd.read_csv('Base_covid19_msp_23abr2020.csv', sep=';', header='infer', encoding='ISO-8859-1')
df_COVID_EC.head()
# Out:
#    anio cod_prov_res prov_residencia cod_cant_res cant_residencia       sexo  \
# 0  2020          '12        LOS RIOS        '1201        BABAHOYO   Femenino
# 1  2020          '12        LOS RIOS        '1201        BABAHOYO   Femenino
# 2  2020          '12        LOS RIOS        '1201        BABAHOYO  Masculino
# 3  2020          '12        LOS RIOS        '1201        BABAHOYO   Femenino
# 4  2020          '12        LOS RIOS        '1201        BABAHOYO  Masculino
#
#    edad tipo_edad       grupo_edad inicio_sintomas  \
# 0    71    Año(s)        mas de 65      2020-02-15
# 1    66    Año(s)        mas de 65      2020-02-27
# 2    36    Año(s)  de 20 a 49 años      2020-02-26
# 3    33    Año(s)  de 20 a 49 años      2020-02-27
# 4    68    Año(s)        mas de 65      2020-02-26
#
#                                          diagnostico condicion_paciente  \
# 0  U071 Enfermedad Respiratoria Aguda (U07.1, 201...             Muerto
# 1  U071 Enfermedad Respiratoria Aguda (U07.1, 201...               Vivo
# 2  U071 Enfermedad Respiratoria Aguda (U07.1, 201...               Vivo
# 3  U071 Enfermedad Respiratoria Aguda (U07.1, 201...               Vivo
# 4  U071 Enfermedad Respiratoria Aguda (U07.1, 201...               Vivo
#
#   clasificacion_caso  total_muestras
# 0         Confirmado               1
# 1         Confirmado               1
# 2         Confirmado               1
# 3         Confirmado               1
# 4         Confirmado               1

# %% [markdown]
# ## Understanding the loaded Dataframe

# %%
#Shows the column headers of the dataframe
df_COVID_EC.columns
# Out:
# Index(['anio', 'cod_prov_res', 'prov_residencia', 'cod_cant_res',
#        'cant_residencia', 'sexo', 'edad', 'tipo_edad', 'grupo_edad',
#        'inicio_sintomas', 'diagnostico', 'condicion_paciente',
#        'clasificacion_caso', 'total_muestras'],
#       dtype='object')

# %%
#Shows the column headers of the dataframe and the data type they represent.
df_COVID_EC.dtypes
# Out:
# anio                   int64
# cod_prov_res          object
# prov_residencia       object
# cod_cant_res          object
# cant_residencia       object
# sexo                  object
# edad                   int64
# tipo_edad             object
# grupo_edad            object
# inicio_sintomas       object
# diagnostico           object
# condicion_paciente    object
# clasificacion_caso    object
# total_muestras         int64
# dtype: object

# %%
# Show some characteristics of the columns tahta contains numeric data
df_COVID_EC.describe()
# Out:
#           anio          edad  total_muestras
# count  35448.0  35448.000000         35448.0
# mean    2020.0     43.212480             1.0
# std        0.0     16.658176             0.0
# min     2020.0      0.000000             1.0
# 25%     2020.0     31.000000             1.0
# 50%     2020.0     40.000000             1.0
# 75%     2020.0     55.000000             1.0
# max     2020.0    120.000000             1.0

# %% [markdown]
# ## Data pre-processing

# %% [markdown]
# So, as said before, the .csv contains a list of all the COVID-19 tests realized in Ecuador until April 23th, 2020. Where each row represents an exam realized on a person.
# <br>
# The aim of this section is to get a dataframe that contains the number of positive COVID-19 cases grouped by each province of the country in order to represent them in the map.

# %%
# Since the groupby method returns a pandas series it is used the name se_provs
#Filter the rows only focusing in positive test result rows from dataframe.
se_provs = df_COVID_EC[df_COVID_EC['clasificacion_caso']=='Confirmado']
# Group the positive tests by provinces with the groupby and count methods.  
se_provs = se_provs.groupby(['prov_residencia']).count()
# locate only the interes coumns for the map ('total_muestras')
se_provs = se_provs.loc[:, 'total_muestras']

# Create an empty data frame
df_provs = pd.DataFrame()
# Add the columns to the new dataframe from the pandas series "se_provs"
df_provs['prov_residencia'] = se_provs.index
df_provs['total_muestras'] = se_provs.values

df_provs
# Out:
#                    prov_residencia  total_muestras
# 0                            AZUAY             285
# 1                          BOLIVAR              66
# 2                           CARCHI              38
# 3                            CAÑAR             166
# 4                       CHIMBORAZO             130
# 5                         COTOPAXI              68
# 6                           EL ORO             300
# 7                       ESMERALDAS             115
# 8                        GALAPAGOS              54
# 9                           GUAYAS            7502
# 10                        IMBABURA              58
# 11                            LOJA             136
# 12                        LOS RIOS             402
# 13                          MANABI             330
# 14                 MORONA SANTIAGO              31
# 15                            NAPO              12
# 16                        ORELLANA              14
# 17                         PASTAZA              25
# 18                       PICHINCHA             991
# 19                     SANTA ELENA             182
# 20  SANTO DOMINGO DE LOS TSACHILAS             123
# 21                       SUCUMBIOS              35
# 22                      TUNGURAHUA              96
# 23                ZAMORA CHINCHIPE              24

# %% [markdown]
# As visible, there is a province with the name "CAÑAR". In programming is preferable to avoid those words and replace them. In this case "CAÑAR" will be replaced with "CANAR".

# %%
df_provs.replace({'CAÑAR': 'CANAR'}, inplace=True)
df_provs
# Out:
#                    prov_residencia  total_muestras
# 0                            AZUAY             285
# 1                          BOLIVAR              66
# 2                           CARCHI              38
# 3                            CANAR             166
# 4                       CHIMBORAZO             130
# 5                         COTOPAXI              68
# 6                           EL ORO             300
# 7                       ESMERALDAS             115
# 8                        GALAPAGOS              54
# 9                           GUAYAS            7502
# 10                        IMBABURA              58
# 11                            LOJA             136
# 12                        LOS RIOS             402
# 13                          MANABI             330
# 14                 MORONA SANTIAGO              31
# 15                            NAPO              12
# 16                        ORELLANA              14
# 17                         PASTAZA              25
# 18                       PICHINCHA             991
# 19                     SANTA ELENA             182
# 20  SANTO DOMINGO DE LOS TSACHILAS             123
# 21                       SUCUMBIOS              35
# 22                      TUNGURAHUA              96
# 23                ZAMORA CHINCHIPE              24

# %% [markdown]
# ## Map Object Creation and layer add

# %% [markdown]
# Create map object and then add choropleth using layer folium library.
# <br>
# For the Choropleth map creation, we will need to read a provs-ec.json file which contains the limits of each province from
# Ecuador.
# <br>
# __geo_data__ Contains the file path to the .json file.
# <br>
# __data__ Contains the name of the dataframe that you are going to use.
# <br>
# __columns__ Contains the columns from the dataframe that will be read. First column is the column that contains the values that match with the data contained in the .json file, provinces name in this case.
# <br>
# __key_on__ Contains the path of the values we want to match with the first column of the dataframe.
# <br>
# __threshold_scale__ Is set by default, but you can redefine the values on it. The only condition is that all the values from de dataframe are contained by the threshold scale.

# %%
# Locate map in Ecuador
ec_map = folium.Map(location=[-1.831239, -78.183403], zoom_start=7, tiles='cartodbpositron') 

ec_geo = r'provs-ec.json' # geojson file
threshold_scale = [1, 50, 150, 350, 1500, 7503]

# generate choropleth map using COVID-19 dataframe
folium.Choropleth(
    geo_data=ec_geo,
    data=df_provs,
    columns=['prov_residencia', 'total_muestras'],
    key_on='feature.properties.dpa_despro',
    fill_color='YlOrRd', 
    fill_opacity=0.7, 
    line_opacity=0.2,
    legend_name='COVID-19 en Ecuador',
    threshold_scale=threshold_scale,
    reset=True,
).add_to(ec_map)

ec_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Now, the Chropleth map is created, but let's try to put markers on it containin information about the exact number of cases from each province.

# %% [markdown]
# ## Load markers location data, using pandas.read_csv

# %% [markdown]
# In order to place the markers it is needed __loc_provs.csv__ file which contains the location of each province capital, and there is where the marker are going to be.

# %%
df_loc_provs = pd.read_csv('loc_provs.csv', sep=',', delimiter=None, header='infer', encoding='ISO-8859-1')
df_loc_provs
# Out:
#                               city       lat        lng  country iso2  \
# 0                        Guayaquil -2.205842 -79.907948  Ecuador   EC
# 1                            Quito -0.194568 -78.493005  Ecuador   EC
# 2                           Cuenca -2.900545 -79.004527  Ecuador   EC
# 3                           Ambato -1.252369 -78.622781  Ecuador   EC
# 4                       Portoviejo -1.054579 -80.454448  Ecuador   EC
# 5                          Machala -3.258608 -79.960535  Ecuador   EC
# 6                       Esmeraldas  0.969112 -79.652018  Ecuador   EC
# 7                         Riobamba -1.670984 -78.647124  Ecuador   EC
# 8                           Ibarra  0.351710 -78.122333  Ecuador   EC
# 9                             Loja -4.005579 -79.202235  Ecuador   EC
# 10                       Latacunga -0.935206 -78.615545  Ecuador   EC
# 11                          Tulcan  0.811871 -77.717271  Ecuador   EC
# 12                        Babahoyo -1.802166 -79.534429  Ecuador   EC
# 13                         Azogues -2.739694 -78.848602  Ecuador   EC
# 14                            Tena -0.993799 -77.812856  Ecuador   EC
# 15                        Guaranda -1.592628 -79.000978  Ecuador   EC
# 16                            Puyo -1.483687 -78.002573  Ecuador   EC
# 17                           Macas -2.308683 -78.111346  Ecuador   EC
# 18                          Zamora -4.066852 -78.954881  Ecuador   EC
# 19         Puerto Baquerizo Moreno -0.923217 -89.604739  Ecuador   EC
# 20                     Santa Elena -2.226222 -80.858725  Ecuador   EC
# 21  Santo Domingo de los Colorados -0.253047 -79.175356  Ecuador   EC
# 22    Puerto Francisco de Orellana -0.466446 -76.987190  Ecuador   EC
# 23                      Nueva Loja  0.090573 -76.888366  Ecuador   EC
#
#                              admin  capital  population  population_proper
# 0                           Guayas    admin   2514000.0          1952029.0
# 1                        Pichincha  primary   1701000.0          1399814.0
# 2                            Azuay    admin    286878.0           276964.0
# 3                       Tungurahua    admin    281425.0           154369.0
# 4                           Manabi    admin    213601.0           170326.0
# 5                           El Oro    admin    213034.0           198123.0
# 6                       Esmeraldas    admin    173101.0            95630.0
# 7                       Chimborazo    admin    172464.0           124478.0
# 8                         Imbabura    admin    146741.0           108666.0
# 9                             Loja    admin    126368.0           117796.0
# 10                        Cotopaxi    admin     94972.0            51717.0
# 11                          Carchi    admin     83000.0            83000.0
# 12                        Los Rios    admin     76279.0            43467.0
# 13                           Cañar    admin     69087.0            34877.0
# 14                            Napo    admin     31126.0            17172.0
# 15                         Bolivar    admin     27866.0            20000.0
# 16                         Pastaza    admin     24881.0            24881.0
# 17                 Morona Santiago    admin     23687.0            17601.0
# 18                Zamora Chinchipe    admin     15276.0             7887.0
# 19                       Galapagos    admin      6030.0             4214.0
# 20                     Santa Elena    admin         NaN                NaN
# 21  Santo Domingo de los Tsachilas    admin         NaN                NaN
# 22                        Orellana    admin         NaN                NaN
# 23                       Sucumbios    admin         NaN                NaN

# %% [markdown]
# Same situation with the "Cañar" province. It is necessary to replace that word with "Canar".

# %%
df_loc_provs.replace({'Cañar': 'Canar'}, inplace=True)
df_loc_provs
# Out:
#                               city       lat        lng  country iso2  \
# 0                        Guayaquil -2.205842 -79.907948  Ecuador   EC
# 1                            Quito -0.194568 -78.493005  Ecuador   EC
# 2                           Cuenca -2.900545 -79.004527  Ecuador   EC
# 3                           Ambato -1.252369 -78.622781  Ecuador   EC
# 4                       Portoviejo -1.054579 -80.454448  Ecuador   EC
# 5                          Machala -3.258608 -79.960535  Ecuador   EC
# 6                       Esmeraldas  0.969112 -79.652018  Ecuador   EC
# 7                         Riobamba -1.670984 -78.647124  Ecuador   EC
# 8                           Ibarra  0.351710 -78.122333  Ecuador   EC
# 9                             Loja -4.005579 -79.202235  Ecuador   EC
# 10                       Latacunga -0.935206 -78.615545  Ecuador   EC
# 11                          Tulcan  0.811871 -77.717271  Ecuador   EC
# 12                        Babahoyo -1.802166 -79.534429  Ecuador   EC
# 13                         Azogues -2.739694 -78.848602  Ecuador   EC
# 14                            Tena -0.993799 -77.812856  Ecuador   EC
# 15                        Guaranda -1.592628 -79.000978  Ecuador   EC
# 16                            Puyo -1.483687 -78.002573  Ecuador   EC
# 17                           Macas -2.308683 -78.111346  Ecuador   EC
# 18                          Zamora -4.066852 -78.954881  Ecuador   EC
# 19         Puerto Baquerizo Moreno -0.923217 -89.604739  Ecuador   EC
# 20                     Santa Elena -2.226222 -80.858725  Ecuador   EC
# 21  Santo Domingo de los Colorados -0.253047 -79.175356  Ecuador   EC
# 22    Puerto Francisco de Orellana -0.466446 -76.987190  Ecuador   EC
# 23                      Nueva Loja  0.090573 -76.888366  Ecuador   EC
#
#                              admin  capital  population  population_proper
# 0                           Guayas    admin   2514000.0          1952029.0
# 1                        Pichincha  primary   1701000.0          1399814.0
# 2                            Azuay    admin    286878.0           276964.0
# 3                       Tungurahua    admin    281425.0           154369.0
# 4                           Manabi    admin    213601.0           170326.0
# 5                           El Oro    admin    213034.0           198123.0
# 6                       Esmeraldas    admin    173101.0            95630.0
# 7                       Chimborazo    admin    172464.0           124478.0
# 8                         Imbabura    admin    146741.0           108666.0
# 9                             Loja    admin    126368.0           117796.0
# 10                        Cotopaxi    admin     94972.0            51717.0
# 11                          Carchi    admin     83000.0            83000.0
# 12                        Los Rios    admin     76279.0            43467.0
# 13                           Canar    admin     69087.0            34877.0
# 14                            Napo    admin     31126.0            17172.0
# 15                         Bolivar    admin     27866.0            20000.0
# 16                         Pastaza    admin     24881.0            24881.0
# 17                 Morona Santiago    admin     23687.0            17601.0
# 18                Zamora Chinchipe    admin     15276.0             7887.0
# 19                       Galapagos    admin      6030.0             4214.0
# 20                     Santa Elena    admin         NaN                NaN
# 21  Santo Domingo de los Tsachilas    admin         NaN                NaN
# 22                        Orellana    admin         NaN                NaN
# 23                       Sucumbios    admin         NaN                NaN

# %% [markdown]
# ## Understanding the loaded Dataframe

# %%
df_loc_provs.columns
# Out:
# Index(['city', 'lat', 'lng', 'country', 'iso2', 'admin', 'capital',
#        'population', 'population_proper'],
#       dtype='object')

# %%
df_loc_provs.dtypes
# Out:
# city                  object
# lat                  float64
# lng                  float64
# country               object
# iso2                  object
# admin                 object
# capital               object
# population           float64
# population_proper    float64
# dtype: object

# %% [markdown]
# ## Adding a marker

# %% [markdown]
# Now we use the folium.marker() method to define and customize the marker, then with the add_too method you can place on your map.

# %%
lat = df_loc_provs['lat'][0]
lng = df_loc_provs['lng'][0]
cad  = df_loc_provs['admin'][0]
folium.Marker([lat,lng], popup=cad).add_to(ec_map)

ec_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Creating markers for each province

# %% [markdown]
# In order to create the markers we have to iterate on the two loaded data frames, because we need the number of cases and the name of the province from the first data set, and then the latitude and longitude and for that same province. So a nested for loop is used.
# <br>
# The Marker object constructor consist of a list that contains [lat, lng], popup that receives the string that contains a message that will be shown when the marker is clicked.
# <br>
# __Note:__ In order to do an iteration on multiple list at the same time, the __zip()__ method is used.

# %%
for lat, lng, label in zip(df_loc_provs.lat, df_loc_provs.lng, df_loc_provs.admin):
	for prov, casos in zip(df_provs.prov_residencia, df_provs.total_muestras):
		if prov == label.upper():
			cad = label + ' ' +  str(casos) + ' casos'
			folium.Marker([lat,lng], popup=cad).add_to(ec_map)

ec_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Display map if you are not using jupyter notebook

# %% [markdown]
# If you are using another python IDE or a text editor, the wont have the display option as Jupyter notebook does, so in order to display the map on those circumstances it will be needed to save the map as an .html file and then open it using the webbrowser library.
# <br>
# The variable filepath should change depending on the path you want to save your map file.

# %%
# Display world map
filepath = 'C:/Users/Hugoa/Notebooks/Map_Ecuador.html'
ec_map.save(filepath)
webbrowser.open('file://' + filepath)
# Out:
# True
